# %%
# %matplotlib inline
# Out:
# /Users/yaolun/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import sys
sys.path.append('/Users/yaolun/programs/misc/hyperion/')
sys.path.append('/Users/yaolun/programs/spectra_analysis/')
from phot_filter import phot_filter
from get_bhr71_obs import get_bhr71_obs
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt
import astropy.constants as const

# constants setup
c = const.c.cgs.value

# %%
wl_aper = [70., 100., 160., 250., 350., 500.]

# %%
obs = '/Users/yaolun/bhr71/obs_for_radmc/'
bhr71 = get_bhr71_obs(obs)
wave_obs, flux_obs, sed_obs_noise = bhr71['spec']

# add IRAC1 and IRAC2 photometry data
wave_obs = np.hstack((wave_obs, bhr71['phot'][0][0:2]))
flux_obs = np.hstack((flux_obs, bhr71['phot'][1][0:2]))
sed_obs_noise = np.hstack((sed_obs_noise, bhr71['phot'][2][0:2]))
# wave_obs = wave_obs[wave_obs > 50]
# flux_obs = flux_obs[wave_obs > 50]
sed_obs = c/(wave_obs*1e-4)*flux_obs*1e-23
sed_obs_noise = c/(wave_obs*1e-4)*sed_obs_noise*1e-23
# print sed_obs_noise
obs_aper_sed = np.empty_like(wl_aper)
obs_aper_sed_noise = np.empty_like(wl_aper)

# sort the wavelength
sed_obs = sed_obs[np.argsort(wave_obs)]
sed_obs_noise = sed_obs_noise[np.argsort(wave_obs)]
wave_obs = wave_obs[np.argsort(wave_obs)]

# calculate the spectrophotometry
for i in range(0, len(wl_aper)):
    # apply the filter function
    # decide the filter name
    if wl_aper[i] == 70:
        fil_name = 'Herschel PACS 70um'
    elif wl_aper[i] == 100:
        fil_name = 'Herschel PACS 100um'
    elif wl_aper[i] == 160:
        fil_name = 'Herschel PACS 160um'
    elif wl_aper[i] == 250:
        fil_name = 'Herschel SPIRE 250um'
    elif wl_aper[i] == 350:
        fil_name = 'Herschel SPIRE 350um'
    elif wl_aper[i] == 500:
        fil_name = 'Herschel SPIRE 500um'
    elif wl_aper[i] == 3.6:
        fil_name = 'IRAC Channel 1'
    elif wl_aper[i] == 4.5:
        fil_name = 'IRAC Channel 2'
    elif wl_aper[i] == 5.8:
        fil_name = 'IRAC Channel 3'
    elif wl_aper[i] == 8.0:
        fil_name = 'IRAC Channel 4'
    elif wl_aper[i] == 24:
        fil_name = 'MIPS 24um'
    # elif wl_aper[i] == 850:
    #     fil_name = 'SCUBA 850WB'
    # do not have SCUBA spectra
    else:
        fil_name = None

    if fil_name != None:
        filter_func = phot_filter(fil_name)
        # Observed SED needs to be trimmed before applying photometry filters
        filter_func = filter_func[(filter_func['wave']/1e4 >= min(wave_obs))*\
                                  ((filter_func['wave']/1e4 >= 54.8)+(filter_func['wave']/1e4 <= 36.0853))*\
                                  ((filter_func['wave']/1e4 <= 95.05)+(filter_func['wave']/1e4 >=103))*\
                                  ((filter_func['wave']/1e4 <= 190.31)+(filter_func['wave']/1e4 >= 195))*\
                                  (filter_func['wave']/1e4 <= max(wave_obs))]
        f = interp1d(wave_obs, sed_obs)
        f_unc = interp1d(wave_obs, sed_obs_noise)
        obs_aper_sed[i] = np.trapz(filter_func['wave']/1e4, f(filter_func['wave']/1e4)*filter_func['transmission'])/np.trapz(filter_func['wave']/1e4, filter_func['transmission'])
        obs_aper_sed_noise[i] = abs(np.trapz((filter_func['wave']/1e4)**2, (f_unc(filter_func['wave']/1e4)*filter_func['transmission'])**2))**0.5 / abs(np.trapz(filter_func['wave']/1e4, filter_func['transmission']))
    else:
        # use a rectangle function the average the simulated SED
        # apply the spectral resolution
        if (wl_aper[i] < 50.) & (wl_aper[i] >= 5):
            res = 60.
        elif wl_aper[i] < 5:
            res = 10.
        else:
            res = 1000.
        ind = np.where((wave_obs < wl_aper[i]*(1+1./res)) & (wave_obs > wl_aper[i]*(1-1./res)))
        if len(ind[0]) != 0:
            obs_aper_sed[i] = np.mean(sed_obs[ind])
            obs_aper_sed_noise[i] = np.mean(sed_obs_noise[ind])
        else:
            f = interp1d(wave_obs, sed_obs)
            f_unc = interp1d(wave_obs, sed_obs_noise)
            obs_aper_sed[i] = f(wl_aper[i])
            obs_aper_sed_noise[i] = f_unc(wl_aper[i])

# %%
# convert Jy to erg/s/cm2 (photometry)
sed_phot = c/(bhr71['phot'][0]*1e-4)*bhr71['phot'][1]*1e-23
sed_phot_noise = c/(bhr71['phot'][0]*1e-4)*bhr71['phot'][2]*1e-23

# %%
print np.shape(bhr71['phot'][0][-6:])
print np.shape(sed_phot)
# Out:
# (6,)
# (15,)

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

ax.errorbar(wl_aper, obs_aper_sed, yerr=obs_aper_sed_noise, fmt='o', mfc='None', markersize=5)
yerr = ( (obs_aper_sed*0.05)**2 + obs_aper_sed_noise**2 )**0.5
for i in range(0,6):
    print sed_phot[-6:][i], obs_aper_sed_noise[i], yerr[i]
ax.errorbar(bhr71['phot'][0][-6:], sed_phot[-6:], yerr=yerr, fmt='o', mfc='None', markersize=5)
ax.plot(bhr71['spec'][0], c/(bhr71['spec'][0]*1e-4)*bhr71['spec'][1]*1e-23)
ax.set_xlim([50,600])

[ax.spines[axis].set_linewidth(1.5) for axis in ['top','bottom','left','right']]
ax.minorticks_on() 
ax.tick_params('both',labelsize=18,width=1.5,which='major',pad=15,length=5)
ax.tick_params('both',labelsize=18,width=1.5,which='minor',pad=15,length=2.5)
ax.set_xlabel(r'$\rm{wavelength\,[\mu m]}$', fontsize=18)
ax.set_ylabel(r'$\rm{\nu S_{\nu}\,[erg,s^{-1}\,cm^{-2}]}$', fontsize=18)

fig.savefig('/Users/yaolun/test/bhr71_herschel.pdf', format='pdf', dpi=300, bbox_inches='tight')
# Out:
# 5.4262434898e-09 1.19979885803e-10 3.13201373335e-10
# 7.19801691658e-09 1.18167837863e-10 4.12036508434e-10
# 4.92409112265e-09 6.59061990266e-11 2.92444780391e-10
# 2.9379660884e-09 2.32396969896e-11 1.57114005884e-10
# 9.9616751044e-10 1.00841571018e-11 5.12099633271e-11
# 2.51226079804e-10 2.45603560812e-12 1.50841947423e-11

# %%
filename = '/Users/yaolun/test/rhoenv.dat'
import numpy as np
import matplotlib.pyplot as plt
rhoenv = np.genfromtxt(filename).T

# %%
print np.shape(rhoenv)
# Out:
# (79, 400)

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
for i in [149,199, 249]:
    ax.plot(rhoenv[:,i])
ax.set_yscale('log')
ax.set_ylim([1e-15, 1e-11])
# Out:
# (1e-15, 1e-11)

# %%
ny = 400
thetai = np.pi*np.arange(ny+1).astype(dtype='float')/float(ny)
thetac = 0.5*(thetai[0:ny]+thetai[1:ny+1])

# %%
print thetac[199]/np.pi
print min(np.sin(np.pi/2-thetac))
# Out:
# 0.49875
# -0.999992289381

# %%
fitsfile = '/Users/yaolun/bhr71/data/bhr71_APEX_continuum/images/BHR71-MM.47543-48830.fits'
from astropy.io import fits
data = fits.open(fitsfile)
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
signal = data[0].data
exposure = data[1].data
noise = data[2].data
snr = data[3].data
# unit: Jy/beam
signal[np.isnan(signal)] = 0

# %%
print signal.max(), signal.min()
# Out:
# 357.62 -175.899

# %%
plt.imshow(signal, cmap=plt.cm.CMRmap, vmin=0, vmax=30)
plt.savefig('/Users/yaolun/test/bhr71_apex.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %%
filename = '/Users/yaolun/bhr71/data/APEXBOL.2013-09-14T13_33_37.000.fits'
data = fits.open(filename)
data[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT     FITS (Flexible Image Transport System) format is defined in 'Astrono
# COMMENT = '        '           /   FITS (Flexible Image Transport System) format
# TELESCOP= 'APEX-12m'           / Telescope Name
# ORIGIN  = 'APEX    '           / Organisation or Institution
# CREATOR = 'FW v6331'           / Software (including version)
# MBFTSVER= '1.64    '           / MBFITS version
# HIERARCH ESO DPR CATG = 'SCIENCE ' / Scan category
# HIERARCH ESO DPR TYPE = 'OBJECT  ' / Scan type
# HIERARCH ESO DPR TECH = 'CONTINUUM' / Scan technique
# HIERARCH ESO OBS PROG ID = '492.L-0466(A)' / ESO program ID, where available. Fo
# HIERARCH ESO OBS ID =     -999 / Observation block ID, where available
# ...

# %%
# for bhr71 calibration 
import numpy as np
from astropy.io import ascii
import matplotlib.pyplot as plt
pacs_b1 = ascii.read('/Users/yaolun/bhr71/calibration_testing/corrected_spec_b1.txt', data_start=4)
pacs_b2 = ascii.read('/Users/yaolun/bhr71/calibration_testing/corrected_spec_b2.txt', data_start=4)
pacs_r1 = ascii.read('/Users/yaolun/bhr71/calibration_testing/corrected_spec_r1.txt', data_start=4)
pacs_r2 = ascii.read('/Users/yaolun/bhr71/calibration_testing/corrected_spec_r2.txt', data_start=4)
spire = ascii.read('/Users/yaolun/bhr71/calibration_testing/spire_sect_100.txt', data_start=4)

# %%
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot(111)

ax.plot(pacs_b1['wave_0'], pacs_b1['flux_0'], linewidth=0.7)
ax.plot(pacs_b2['wave_0'], pacs_b2['flux_0'], linewidth=0.7)
ax.plot(pacs_r1['wave_0'], pacs_r1['flux_0'], linewidth=0.7)
ax.plot(pacs_r2['wave_0'], pacs_r2['flux_0'], linewidth=0.7)
ax.plot(spire['wave_0'], spire['flux_0'], linewidth=0.7)
ax.plot(spire['wave_1'], spire['flux_1'], linewidth=0.7)

[ax.spines[axis].set_linewidth(1.5) for axis in ['top','bottom','left','right']]
ax.minorticks_on() 
ax.tick_params('both',labelsize=18,width=1.5,which='major',pad=15,length=5)
ax.tick_params('both',labelsize=18,width=1.5,which='minor',pad=15,length=2.5)
ax.set_xlabel(r'$\rm{Wavelength\,[\mu m]}$', fontsize=18)
ax.set_ylabel(r'$\rm{Flux\,Density\,[Jy]}$', fontsize=18)

fig.savefig('/Users/yaolun/bhr71/calibration_testing/semi-extended_correction.pdf',
            format='pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Test the effect of $\tt{gaussRefBeamDiam}$

# %%
spire = ascii.read('/Users/yaolun/bhr71/calibration_testing/spire_sect_100.txt', data_start=4)
import numpy as np
from astropy.io import ascii
import matplotlib.pyplot as plt

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import astropy.constants as const
c = const.c.cgs.value

# %%
filename = '/Users/yaolun/bhr71/data/single_dish_TB/bhr71-hcop32.sest.fits'
data = fits.open(filename)
# Out:
# WARNING: Header block contains null bytes instead of spaces for padding, and is not FITS-compliant. Nulls may be replaced with spaces upon writing. [astropy.io.fits.header]
# WARNING:astropy:Header block contains null bytes instead of spaces for padding, and is not FITS-compliant. Nulls may be replaced with spaces upon writing.

# %%
data[0].header
# Out:
# SIMPLE  =                    T         /
# BITPIX  =                  -64
# NAXIS   =                    4         /
# NAXIS1  =                 1000         /
# NAXIS2  =                    1         /
# NAXIS3  =                    1         /
# NAXIS4  =                    1         /
# BLOCKED =                    T         /
# DATAMIN = -0.253184747696E+001         /
# DATAMAX =  0.352531838417E+001         /
# BUNIT   = 'K       '                   /
# CTYPE1  = 'FREQ    '                   /
# CRVAL1  =  0.000000000000E+000         / Offset frequency
# CDELT1  = -0.416771993041E+005         / Frequency resolution
# CRPIX1  =  0.501000000000E+003         /
# CTYPE2  = 'RA--    '                   /
# EQUINOX =  0.195000000000E+004         /
# CRVAL2  =  0.179759583840E+003         /
# CDELT2  =  0.000000000000E+000         /
# CRPIX2  =  0.000000000000E+000         /
# CTYPE3  = 'DEC-    '                   /
# CRVAL3  = -0.648669469500E+002         /
# ...

# %%
spec = data[0].data.squeeze()
refpix = data[0].header['CRPIX1']
res = data[0].header['CDELT1']
rest_f = data[0].header['RESTFREQ']
freq = (refpix-np.arange(len(spec)))*(res/rest_f*c)

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

ax.plot(freq[100:-100]/1e5, spec[100:-100])

[ax.spines[axis].set_linewidth(1.5) for axis in ['top','bottom','left','right']]
ax.minorticks_on() 
ax.tick_params('both',labelsize=18,width=1.5,which='major',pad=15,length=5)
ax.tick_params('both',labelsize=18,width=1.5,which='minor',pad=15,length=2.5)
ax.set_xlabel(r'$\rm{\Delta v\,[km\,s^{-1}]}$', fontsize=18)
ax.set_ylabel(r'$\rm{T\,[K]}$', fontsize=18)

ax.set_xlim([-10,10])

fig.savefig('/Users/yaolun/bhr71/data/single_dish_TB/hcop3-2.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %%
from hyperion.model import ModelOutput
import astropy.constants as const
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pc = const.pc.cgs.value
c = const.c.cgs.value
dstar = 200*pc
freq = 345e9

# %%
filename = '/Users/yaolun/test/model_alma/model_alma3.rtout'
m = ModelOutput(filename)
sed = m.get_sed(group=0, inclination=0, aperture='all', distance=dstar, units='mJy')
aper = np.linspace(0.27, 9.09,10)

# %%
print sed.val
plt.plot(aper, sed.val, 'o-', mec='None')
# Out:
# [[    5.31101685]
#  [   10.39144819]
#  [   20.15694306]
#  [   39.59863552]
#  [   75.58565879]
#  [  138.82493889]
#  [  247.07943078]
#  [  429.51000244]
#  [  738.14875811]
#  [ 1233.27492142]]

# %%
from astropy.io import ascii
data = ascii.read('/Users/yaolun/bhr71/best_calibrated/BHR71_pacs_weighted.txt')
res1 = ascii.read('/Users/yaolun/programs/line_fitting/spectralresolution_order1.txt',
                  names=['wave','res'])
res2 = ascii.read('/Users/yaolun/programs/line_fitting/spectralresolution_order2.txt',
                  names=['wave','res'])
res3 = ascii.read('/Users/yaolun/programs/line_fitting/spectralresolution_order3.txt',
                  names=['wave','res'])
fwhm1 = res1['wave']/res1['res']
fwhm2 = res2['wave']/res2['res']
fwhm3 = res3['wave']/res3['res']
print len(data)
# Out:
# 7092

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(res1['wave'], fwhm1)
plt.plot(res2['wave'], fwhm2)
print np.mean(fwhm1), np.mean(fwhm2)
# Out:
# 0.118580635752 0.0370183908336

# %%
seg1 = data['Wavelength(um)'][data['Wavelength(um)'] < 100]
seg2 = data['Wavelength(um)'][data['Wavelength(um)'] > 100]
print np.mean(fwhm1)/np.mean(seg1[1:]-seg1[:-1]), np.mean(fwhm2)/np.mean(seg2[1:]-seg2[:-1])
print (len(seg1)/12.4+len(seg2)/1.22)*0.003
# Out:
# 12.4040188806 1.22177674661
# 8.105433633

# %%
spire = ascii.read('/Users/yaolun/bhr71/best_calibrated/BHR71_spire_corrected.txt')
import astropy.constants as const
c = const.c.cgs.value

freq = c/spire['Wavelength(um)']/1e-4/1e9

# %%
1.4/np.mean(freq[:-1]-freq[1:])
print len(freq)/4.67*0.003
# Out:
# 2.33704496788

# %%
from astropy.io import ascii
data = ascii.read('/Users/yaolun/bhr71/hyperion/model158_sed_inf.txt')
aper72 = ascii.read('/Users/yaolun/Downloads/bhr71_simulations/bhr71_sed_7.2.txt')
aper204 = ascii.read('/Users/yaolun/Downloads/bhr71_simulations/bhr71_sed_20.4.txt')

# %%
import matplotlib.pyplot as plt
import astropy.constants as const
c = const.c.cgs.value

# %matplotlib inline
plt.plot(data['wave'], data['vSv']/(c/data['wave']/1e-4)*1e23)
plt.plot(aper72['wave'], aper72['vSv']/(c/aper72['wave']/1e-4)*1e23)
plt.plot(aper204['wave'], aper204['vSv']/(c/aper204['wave']/1e-4)*1e23)
plt.xlim([0,30])
plt.ylim([0,2])
# Out:
# (0, 2)

# %%
from astropy.io import ascii
import matplotlib.pyplot as plt
import sys
sys.path.append('/Users/yaolun/programs/misc/hyperion/')
from get_obs import get_obs
sim = ascii.read('/Users/yaolun/bhr71/hyperion/controlled/model65_sed_w_aperture.txt')
obs = get_obs('/Users/yaolun/bhr71/best_calibrated/')

# %%
sim
# Out:
# <Table length=21>
#   wave      vSv      sigma_vSv
# float64   float64     float64
# ------- ----------- -----------
#     3.6 1.91959e-11 2.76964e-13
#     4.5 3.75618e-11 4.28145e-13
#     5.8 4.49971e-11 4.21782e-13
#     8.0 4.59128e-11 2.92993e-13
#     8.5 5.17022e-11 4.33115e-12
#     9.0 2.52846e-11 1.77575e-12
#     9.7  4.8274e-12 5.16174e-13
#    10.0 2.90635e-12 3.32595e-13
#    10.5 4.19184e-12  4.8605e-13
#    11.0 3.89532e-12 2.56239e-13
#    16.0 9.37194e-11  3.8624e-12
#    20.0 1.78016e-10 5.56929e-12
#    24.0 5.79346e-10  1.7229e-12
#    30.0 1.51586e-09 2.81607e-11
#    70.0 6.37801e-09 6.21228e-12
#   100.0 6.13481e-09 5.47092e-12
#   160.0 3.73221e-09  2.1338e-12
#   250.0   1.509e-09 9.48743e-13
#   350.0 6.74134e-10 4.29972e-13
#   500.0 1.90682e-10 1.37308e-13
#  1300.0 5.44861e-12 1.67665e-14

# %%
# %matplotlib inline

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

import astropy.constants as const
import numpy as np
c = const.c.cgs.value

sim_yerrhi = np.log10(sim['vSv'][sim['wave'] >= 70]+sim['sigma_vSv'][sim['wave'] >= 70]) - np.log10(sim['vSv'][sim['wave'] >= 70])
sim_yerrlow = np.log10(sim['vSv'][sim['wave'] >= 70]) - np.log10(sim['vSv'][sim['wave'] >= 70]-sim['sigma_vSv'][sim['wave'] >= 70])

ax.errorbar(np.log10(sim['wave'][sim['wave'] >= 70]), np.log10(sim['vSv'][sim['wave'] >= 70]), yerr=[sim_yerrlow, sim_yerrhi],
        fmt='o', markersize=10, markeredgewidth=1.5, mec='g', ecolor='g', color='None', elinewidth=1.2, capthick=1.2, barsabove=True)

obs_yerrhi = np.log10(obs['phot'][1][obs['phot'][0] >= 70]*(c*1e4/obs['phot'][0][obs['phot'][0] >= 70])*1e-23+\
                      obs['phot'][2][obs['phot'][0] >= 70]*(c*1e4/obs['phot'][0][obs['phot'][0] >= 70])*1e-23)-\
             np.log10(obs['phot'][1][obs['phot'][0] >= 70]*(c*1e4/obs['phot'][0][obs['phot'][0] >= 70])*1e-23)
obs_yerrlow = np.log10(obs['phot'][1][obs['phot'][0] >= 70]*(c*1e4/obs['phot'][0][obs['phot'][0] >= 70])*1e-23)-\
              np.log10(obs['phot'][1][obs['phot'][0] >= 70]*(c*1e4/obs['phot'][0][obs['phot'][0] >= 70])*1e-23-\
                       obs['phot'][2][obs['phot'][0] >= 70]*(c*1e4/obs['phot'][0][obs['phot'][0] >= 70])*1e-23)
ax.errorbar(obs['phot'][0][obs['phot'][0] >= 70],
        obs['phot'][1][obs['phot'][0] >= 70]*(c*1e4/obs['phot'][0][obs['phot'][0] >= 70])*1e-23,
        yerr=obs['phot'][2][obs['phot'][0] >= 70]*(c*1e4/obs['phot'][0][obs['phot'][0] >= 70])*1e-23,
        fmt='o', linestyle='-', markersize=10, markeredgewidth=1.5,
        color='None', mec='b',ecolor='b', elinewidth=1.2, capthick=1.2, barsabove=True)
# Out:
# <Container object of 3 artists>
