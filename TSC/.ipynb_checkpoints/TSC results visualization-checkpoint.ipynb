# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii
import seaborn as sns
from matplotlib.colors import LogNorm

sns.set_style("ticks")

# %%
filename = '/Users/yaolun/programs/misc/TSC/rho_v_env'
data = ascii.read(filename)
print data.colnames
# Out:
# ['lp', 'xr', 'theta', 'ro', 'ur', 'utheta', 'uphi']

# %%
nxr = len(np.unique(data['xr']))
ntheta = len(np.unique(data['theta']))
rho2d = data['ro'].reshape([nxr, ntheta])
print np.shape(rho2d), rho2d.min(), rho2d.max()
# Out:
# (50, 100) 2.06139278 1529.02258

# %%
fig = plt.figure(figsize=(8,6))
ax  = fig.add_subplot(111,projection='polar')

ax.pcolormesh(np.unique(data['theta']), np.unique(data['xr']), rho2d, norm=LogNorm(vmin=rho2d.min(),vmax=rho2d.max()))

# %%
a = 0.38e5
tcol = 36000.*3600*24*365
R_inf = a*tcol
